# %%
name = '2015-09-14-SWC'

title = "An open source story: from the classroom to a bug fix"

import warnings

# %%
# %matplotlib inline

import os
import seaborn
from datetime import datetime
from IPython.core.display import HTML

with open('creative_commons.txt', 'r') as f:
    html = f.read()


hour = datetime.utcnow().strftime('%H:%M')
comments="true"


date = '-'.join(name.split('-')[:3])
slug = '-'.join(name.split('-')[3:])

metadata = dict(title=title,
                date=date,
                hour=hour,
                comments=comments,
                slug=slug,
                name=name)

markdown = """Title: {title}
date:  {date} {hour}
comments: {comments}
slug: {slug}

{{% notebook {name}.ipynb cells[2:] %}}
""".format(**metadata)

content = os.path.abspath(os.path.join(os.getcwd(),
                                       os.pardir,
                                       os.pardir, 
                                       '{}.md'.format(name)))
with open('{}'.format(content), 'w') as f:
    f.writelines(markdown)
    
with open('./styles/custom.css', 'r') as f:
    styles = f.read()


html = """
<small>
<p> This post was written as an IPython notebook.  It is available for
<a href="http://ocefpaf.github.com/python4oceanographers/downloads/
notebooks/%s.ipynb">download</a> or as a static
<a href="http://nbviewer.ipython.org/url/ocefpaf.github.com/
python4oceanographers/downloads/notebooks/%s.ipynb">html</a>.</p>
<p></p>
# %s """ % (name, name, html)


HTML(styles)
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
# /*        margin-left:16% !important;
#         margin-right:auto;*/
#         margin-left:auto;
#         margin-right:16% !important;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h2 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 135%;
#         font-size: 120%;
#         width:600px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
# /*    .prompt{
#         display: None;
#     }*/
# ...

# %% [markdown]
# Last week I had the pleasure of teaching my first
# [Software Carpentry](https://software-carpentry.org/)
# [Workshop](http://ocefpaf.github.io/2015-08-31-UFBA/) at
# [UFBA](https://www.ufba.br/).  After the 2-day workshop we had another 3 extra days
# of [python training for oceanographers](http://ocefpaf.github.io/python4oceanographers_intro_course/).
#
# We did not had internet connection for the workshop, nor a room with enough
# power outlets.  That was a bummer, but we manage by providing copies of all the
# software we used in flashdrives, and bringing extension cords and power strips.
# Only a few examples that demanded some downloading had to be left out.  Besides that
# the workshop went smoothly.
#
# I will write more about the workshop in another post for SWC. Here I want to
# tell a story of what happened in the workshop.
#
# At the last day, during an exercise, a student decided to mix a cartopy plot of
# an OpenStreetMaps image with another cartopy example using quiver.
# Surprisingly we found a bug in cartopy that, when transforming coordinates to
# plot a quiver, it raise a `ValueError` for 1D data.
#
# What follows next is a nice example of how the Open Source (OS) world works.
# We opened an issue on [GitHub](https://github.com/SciTools/cartopy/issues/672)
# and sent our own hackish fix as a [PR](https://github.com/SciTools/cartopy/pull/674).
#
# After a typical OS conversation on the issue tracker and on the PR page one of
# cartopy's core developers, Phil Elson, started a
# [proper PR](https://github.com/SciTools/cartopy/pull/677) with unit tests and
# everything to fix the bug.  Phil Elson, as the polite British lord he is, even used
# part of our original commit is his PR.
#
# Long story short: we may now pass 1D data with cartopy when transforming
# between coordinates.
#
# This story might be your everyday bread-and-butter if you are already in the
# OS world.  But for students that are just starting with programming, or coming
# from closed source software like Matlab, it means a lot to see that they can
# make a difference.  I hope that next time they open issue themselves, maybe
# even send the PR on thier own.
#
# To finish my post I will add a SWC Instructors/Attendees graph.

# %% [markdown]
# Let's load the data with pandas.

# %%
from pandas import read_csv


df = read_csv('./data/per-capita.csv', index_col=0)

# %%
df['Population'] = df['Population'] / 1e6
df['Attendees'] = df['Attendees'] / df['Population'] 
df['Instructors'] = df['Instructors'] / df['Population']

# %% [markdown]
# The cell below creates a simple CSS for the table.

# %%
table = """
table
{
  border-collapse: collapse;
}
th
{
  color: #ffffff;
  background-color: #000000;
}
td
{
  background-color: #cccccc;
}
table, th, td
{
  font-family:Arial, Helvetica, sans-serif;
  border: 1px solid black;
  text-align: right;
}
"""

# %% [markdown]
# The we will plot it using an interactive figure created with mpld3.

# %%
import numpy as np
import matplotlib.pyplot as plt

import mpld3
from mpld3 import plugins

# %matplotlib inline

mpld3.enable_notebook()


labels = []
for k in range(df.index.size):
    label = df.ix[[k], :].T
    labels.append(str(label.to_html()))

fig, ax = plt.subplots()
ax.grid(True, alpha=0.3)
kw = dict(marker='o', color='b', markeredgecolor='k', markersize=5,
          markeredgewidth=1, alpha=0.6, linestyle='none')
points = ax.plot(df['Attendees'], df['Instructors'], **kw)
ax.set_xlabel('Attendees per million pop')
ax.set_ylabel('Instructors per million pop')
ax.axis([-0.5, 35, -0.1, 1.4])

tooltip = plugins.PointHTMLTooltip(points[0], labels,
                                   voffset=10, hoffset=10, css=table)
plugins.connect(fig, tooltip)

# %%
mpld3.disable_notebook()

# %% [markdown]
# That is nice, but let's get fancy with matplotlib and add some flags.
#
# (You have to download  the flags from http://vathanx.deviantart.com/art/World-Flag-Icons-PNG-108083900 first.)

# %%
from glob import glob
flags = glob('./data/flags/*.png')


def split_flag(flag):
    return ' '.join(flag.split('.')[1:-1][0].split()[2:])

# %%
import matplotlib.pyplot as plt
from matplotlib._png import read_png
from matplotlib.offsetbox import AnnotationBbox, OffsetImage


def make_plot(ax):
    ax.scatter(df['Attendees'], df['Instructors'], )

    for (label, x, y) in zip(df.index, df['Attendees'], df['Instructors']):
        for flag in flags:
            flag_name = split_flag(flag)
            if label == flag_name:
                png = read_png(flag)
                imagebox = OffsetImage(png, zoom=.1)
                ab = AnnotationBbox(imagebox, xy=(x,y), frameon=False,
                                    xycoords='data',
                                    boxcoords='data')
                ab.set_alpha(0)
                ax.add_artist(ab)

fig, ax = plt.subplots(figsize=(7, 7))
ax.set_xlabel('Attendees per million pop')
ax.set_ylabel('Instructors per million pop')
make_plot(ax)

# %% [markdown]
# If you could not find Brazil in any of those graphs, or if you did find it and
# saw the numbers, you now understand the need for more workshops!

# %%
HTML(html)
# Out:
# <small>
# <p> This post was written as an IPython notebook.  It is available for
# <a href="http://ocefpaf.github.com/python4oceanographers/downloads/
# notebooks/2015-09-14-SWC.ipynb">download</a> or as a static
# <a href="http://nbviewer.ipython.org/url/ocefpaf.github.com/
# python4oceanographers/downloads/notebooks/2015-09-14-SWC.ipynb">html</a>.</p>
# <p></p>
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img
# alt="Creative Commons License" style="border-width:0"
# src="http://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br /><span
# xmlns:dct="http://purl.org/dc/terms/"
# property="dct:title">python4oceanographers</span> by <a
# xmlns:cc="http://creativecommons.org/ns#" href="http://ocefpaf.github.io/"
# property="cc:attributionName" rel="cc:attributionURL">Filipe Fernandes</a> is
# licensed under a <a rel="license"
# href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons
# ...

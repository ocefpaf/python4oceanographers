# %%
from IPython.core.display import HTML

with open('creative_commons.txt', 'r') as f:
    html = f.read()
    
with open('./styles/custom.css', 'r') as f:
    styles = f.read()
    
HTML(styles)

name = '2014-01-27-bat'

html = """
<small>
<p> This post was written as an IPython notebook.  It is available for
<a href="http://ocefpaf.github.com/python4oceanographers/downloads/
notebooks/%s.ipynb">download</a> or as a static
<a href="http://nbviewer.ipython.org/url/ocefpaf.github.com/
python4oceanographers/downloads/notebooks/%s.ipynb">html</a>.</p>
<p></p>
# %s """ % (name, name, html)

# %% [markdown]
# This post will be a short and simple one.  I could not prepare anything more
# elaborated for this week because I was out on a much deserved
# [holiday](http://en.wikipedia.org/wiki/Chapada_Diamantina_National_Park).
#
# It is a quick example on how to use [sympy](http://sympy.org/en/index.html),
# to evaluate and plot functions.
#
# Lets start!
#
# The cell bellow activates Sympy's printing functionality.
# Now any `function` object will be displayed as latex equation that gets
# automagically rendered by the IPython notebook.

# %%
from sympy.interactive import printing
printing.init_printing()

# %% [markdown]
# The functions we are using contain two variables (*x*, *y*) that are
# represented by sympy's `symbols` object.  We also need sympy's `sqrt`.
# (This `sqrt` is different from either numpy's and math's `sqrt`
# functions.)  Last but not least we need the `Function` class to build the
# function objects.
#
# Note: The `S` is to simplify the functions.  We do not need it unless
# initializing the equation with quotes.  But, by doing so, sympy won't evaluate
# any number expression.

# %%
from sympy import Function, symbols, sqrt, S

x, y = symbols("x y")

# %% [markdown]
# Here we create the 5 functions named by color.  (The colors will help to
# identify them later in the plot.)

# %%
red = S("(x / 7) ** 2 * sqrt(abs(abs(x) - 3) / (abs(x) - 3)) + (y / 3) ** 2 * sqrt(abs(y + 3 / 7 * sqrt(33)) / (y + 3 / 7 * sqrt(33))) - 1")
red
# Out:
#                                         ___________________
#                                        ╱    ⎛        ____⎞
#                                       ╱     ⎜    3⋅╲╱ 33 ⎟
#                                      ╱   abs⎜y + ────────⎟
#                             2       ╱       ⎝       7    ⎠
#                            y ⋅     ╱     ─────────────────
#        _________________          ╱                 ____
#  2    ╱ abs(abs(x) - 3)          ╱              3⋅╲╱ 33
# x ⋅  ╱  ───────────────         ╱           y + ────────
#    ╲╱      abs(x) - 3         ╲╱                   7
# ──────────────────────── + ──────────────────────────────── - 1
#            49                             9

# %%
orange = S("abs(x / 2) - ((3 * sqrt(33) - 7) / 112) * x ** 2 - 3 + sqrt(1 - (abs(abs(x) - 2) - 1) ** 2) - y")
orange
# Out:
#      ⎛           ____⎞          ______________________________
#    2 ⎜  1    3⋅╲╱ 33 ⎟         ╱                        2           ⎛x⎞
# - x ⋅⎜- ── + ────────⎟ - y + ╲╱  - (abs(abs(x) - 2) - 1)  + 1  + abs⎜─⎟ - 3
#      ⎝  16     112   ⎠                                              ⎝2⎠

# %%
green = S("9 * sqrt(abs((abs(x) - 1) * (abs(x) - 0.75)) / ((1 - abs(x)) * (abs(x) - 0.75))) - 8 * abs(x) - y")
green
# Out:
#            ___________________________________
#           ╱ abs((abs(x) - 1)⋅(abs(x) - 0.75))
# -y + 9⋅  ╱  ─────────────────────────────────  - 8⋅abs(x)
#        ╲╱     (-abs(x) + 1)⋅(abs(x) - 0.75)

# %%
blue = S("3 * abs(x) + 0.75 * sqrt(abs((abs(x) - 0.75) * (abs(x) - 0.5)) / ((0.75 - abs(x)) * (abs(x) - 0.5))) - y")
blue
# Out:
#               _____________________________________
#              ╱ abs((abs(x) - 0.75)⋅(abs(x) - 0.5))
# -y + 0.75⋅  ╱  ───────────────────────────────────  + 3⋅abs(x)
#           ╲╱     (-abs(x) + 0.75)⋅(abs(x) - 0.5)

# %%
pink = S("2.25 * sqrt(abs((x - 0.5) * (x + 0.5)) / ((0.5 - x) * (0.5 + x))) - y")
pink
# Out:
#               __________________________
#              ╱ abs((x - 0.5)⋅(x + 0.5))
# -y + 2.25⋅  ╱  ────────────────────────
#           ╲╱     (-x + 0.5)⋅(x + 0.5)

# %%
brown = S("6 * sqrt(10) / 7 + (1.5 - 0.5 * abs(x)) * sqrt(abs(abs(x) - 1) / (abs(x) - 1)) - (6 * sqrt(10) / 14) * sqrt(4 - (abs(x) - 1) ** 2) - y")
brown
# Out:
#                                                              _________________
#          _________________                           ____   ╱               2
#         ╱ abs(abs(x) - 1)                        3⋅╲╱ 10 ⋅╲╱  - (abs(x) - 1)
# -y +   ╱  ─────────────── ⋅(-0.5⋅abs(x) + 1.5) - ─────────────────────────────
#      ╲╱      abs(x) - 1                                          7
#
# ____
#            ____
# + 4    6⋅╲╱ 10
# ──── + ────────
#           7

# %% [markdown]
# It is fun to play with sympy's functions, just check the
# [docs](http://docs.sympy.org/dev/tutorial/index.html) out  and be amazed!
# There are tons of possibilities.
#
# In the next cell we use `lambdify` to evaluate the
# expressions as numpy functions.

# %%
from sympy import lambdify

def lamb(func):
    return lambdify((x, y), func, modules='numpy')

red, orange, green, blue, pink, brown = map(lamb, (red, orange, green, blue, pink, brown))

# %% [markdown]
# Now it is easy to evaluate the functions at any given grid.
# (Ignore the warnings, we do not need the imaginary values.)

# %%
import numpy as np

spacing = 0.01
x, y = np.meshgrid(np.arange(-7.25, 7.25, spacing),
                   np.arange(-5, 5, spacing))

red = red(x, y)
orange = orange(x, y)
green = green(x, y)
blue = blue(x, y)
pink = pink(x, y)
brown = brown(x, y)

# %% [markdown]
# Finally lets plot the figure with matplotlib.

# %%
import matplotlib.pyplot as plt

colors = dict(red='#FF0000', orange='#FFA500', green='#008000',
              blue='#003399', pink='#CC0033', brown='#800000')

equations = dict(red=red, orange=orange, green=green,
                 blue=blue, pink=pink, brown=brown)
                 
fig, ax = plt.subplots(figsize=(8, 6))
for key, color in colors.items():
    ax.contour(x, y, equations[key], [0], colors=color, linewidths=3)
    
_ = ax.set_xticks([])
_ = ax.set_yticks([])

# %% [markdown]
# You can find these functions at [wolfram](http://www.wolframalpha.com/input/?i=batman+equation).
# But we did not find any bat in the caves we visit during our vacation time... But we did find just this though:

# %%
from IPython.display import Image
Image('../../images/poco_encantado.jpg')

# %%
HTML(html)
# Out:
# <small>
# <p> This post was written as an IPython notebook.  It is available for
# <a href="http://ocefpaf.github.com/python4oceanographers/downloads/
# notebooks/2014-01-27-bat.ipynb">download</a> or as a static
# <a href="http://nbviewer.ipython.org/url/ocefpaf.github.com/
# python4oceanographers/downloads/notebooks/2014-01-27-bat.ipynb">html</a>.</p>
# <p></p>
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img
# alt="Creative Commons License" style="border-width:0"
# src="http://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br /><span
# xmlns:dct="http://purl.org/dc/terms/"
# property="dct:title">python4oceanographers</span> by <a
# xmlns:cc="http://creativecommons.org/ns#" href="http://ocefpaf.github.io/"
# property="cc:attributionName" rel="cc:attributionURL">Filipe Fernandes</a> is
# licensed under a <a rel="license"
# href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons
# ...

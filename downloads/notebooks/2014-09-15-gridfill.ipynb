# %%
from IPython.core.display import HTML

with open('creative_commons.txt', 'r') as f:
    html = f.read()
    
with open('./styles/custom.css', 'r') as f:
    styles = f.read()
    
HTML(styles)

name = '2014-07-14-gridfill'

html = """
<small>
<p> This post was written as an IPython notebook.  It is available for
<a href="http://ocefpaf.github.com/python4oceanographers/downloads/
notebooks/%s.ipynb">download</a> or as a static
<a href="http://nbviewer.ipython.org/url/ocefpaf.github.com/
python4oceanographers/downloads/notebooks/%s.ipynb">html</a>.</p>
<p></p>
# %s """ % (name, name, html)

import seaborn
# %matplotlib inline

# %%
import numpy as np
import numpy.ma as ma
import matplotlib.pyplot as plt

from gridfill import fill

# %% [markdown]
# ```python
# Type:        function
# String form: <function fill at 0x7fdad7d51050>
# File:        /usr/lib64/python3.3/site-packages/gridfill/gridfill.py
# Definition:  fill(grids, xdim, ydim, eps, relax=0.6, itermax=100, initzonal=False, cyclic=False, verbose=False)
# Docstring:
# Fill missing values in grids with values derived by solving
# Poisson's equation using a relaxation scheme.
#
# **Arguments:**
#
# *grid*
#     A masked array with missing values to fill.
#
# *xdim*, *ydim*
#     The numbers of the dimensions in *grid* that represent the
#     x-coordinate and y-coordinate respectively.
#
# *eps*
#     Tolerance for determining the solution complete.
#
# **Keyword arguments:**
#
# *relax*
#     Relaxation constant. Usually 0.45 <= *relc* <= 0.6. Defaults to
#     0.6.
#
# *itermax*
#     Maximum number of iterations of the relaxation scheme. Defaults
#     to 100 iterations.
#
# *initzonal*
#     If *False* missing values will be initialized to zero, if *True*
#     missing values will be initialized to the zonal mean. Defaults
#     to *False*.
#
# *cyclic*
#     Set to *False* if the x-coordinate of the grid is not cyclic,
#     set to *True* if it is cyclic. Defaults to *False*.
#
# *verbose*
#     If *True* information about algorithm performance will be
#     printed to stdout, if *False* nothing is printed. Defaults to
#     *False*.
# ```

# %%
grid = ma.masked_invalid(np.load('./data/grid.npy'))

# %%
# Parameters for relaxation scheme, same for all tests.
kw = dict(eps=1e-4, relax=0.6, itermax=2000, initzonal=False,
          cyclic=False, verbose=False)

filled, c = fill(grid[0], 1, 0, **kw)

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2, figsize=(7, 11),
                               sharex=True, sharey=True, )

cs0 = ax0.pcolorfast(np.rot90(grid[0].T))
cs1 = ax1.pcolorfast(np.rot90(filled.T))

# %%
HTML(html)
# Out:
# <small>
# <p> This post was written as an IPython notebook.  It is available for
# <a href="http://ocefpaf.github.com/python4oceanographers/downloads/
# notebooks/2014-07-14-gridfill.ipynb">download</a> or as a static
# <a href="http://nbviewer.ipython.org/url/ocefpaf.github.com/
# python4oceanographers/downloads/notebooks/2014-07-14-gridfill.ipynb">html</a>.</p>
# <p></p>
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img
# alt="Creative Commons License" style="border-width:0"
# src="http://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br /><span
# xmlns:dct="http://purl.org/dc/terms/"
# property="dct:title">python4oceanographers</span> by <a
# xmlns:cc="http://creativecommons.org/ns#" href="http://ocefpaf.github.io/"
# property="cc:attributionName" rel="cc:attributionURL">Filipe Fernandes</a> is
# licensed under a <a rel="license"
# href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons
# Attribution-ShareAlike 4.0 International License</a>.<br />Based on a work at <a
# xmlns:dct="http://purl.org/dc/terms/" href="http://ocefpaf.github.io/"
# rel="dct:source">http://ocefpaf.github.io/</a>.

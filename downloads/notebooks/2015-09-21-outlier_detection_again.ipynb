# %%
name = '2015-08-10-outlier_detection_again'

title = ""

# %%
# %matplotlib inline

import os
import seaborn
from datetime import datetime
from IPython.core.display import HTML

with open('creative_commons.txt', 'r') as f:
    html = f.read()


hour = datetime.utcnow().strftime('%H:%M')
comments="true"


date = '-'.join(name.split('-')[:3])
slug = '-'.join(name.split('-')[3:])

metadata = dict(title=title,
                date=date,
                hour=hour,
                comments=comments,
                slug=slug,
                name=name)

markdown = """Title: {title}
date:  {date} {hour}
comments: {comments}
slug: {slug}

{{% notebook {name}.ipynb cells[2:] %}}
""".format(**metadata)

content = os.path.abspath(os.path.join(os.getcwd(),
                                       os.pardir,
                                       os.pardir, 
                                       '{}.md'.format(name)))
with open('{}'.format(content), 'w') as f:
    f.writelines(markdown)
    
with open('./styles/custom.css', 'r') as f:
    styles = f.read()


html = """
<small>
<p> This post was written as an IPython notebook.  It is available for
<a href="http://ocefpaf.github.com/python4oceanographers/downloads/
notebooks/%s.ipynb">download</a> or as a static
<a href="http://nbviewer.ipython.org/url/ocefpaf.github.com/
python4oceanographers/downloads/notebooks/%s.ipynb">html</a>.</p>
<p></p>
# %s """ % (name, name, html)


HTML(styles)
# Out:
# /home/filipe/.virtualenvs/blog/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
# /*        margin-left:16% !important;
#         margin-right:auto;*/
#         margin-left:auto;
#         margin-right:16% !important;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h2 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 135%;
#         font-size: 120%;
#         width:600px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
# /*    .prompt{
#         display: None;
#     }*/
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
from datetime import datetime
from pandas import read_table

fname = './data/spikey_v.dat'
cols = ['j', 'u', 'v', 'temp', 'sal', 'y', 'mn', 'd', 'h', 'mi']

df = read_table(fname , delim_whitespace=True, names=cols)

df.index = [datetime(*x) for x in zip(df['y'], df['mn'], df['d'], df['h'], df['mi'])]
df = df.drop(['y', 'mn', 'd', 'h', 'mi'], axis=1)

df.head()
# Out:
#                              j    u    v  temp   sal
# 1994-11-22 04:00:00  1056.1667 -0.1  0.0  23.9  34.6
# 1994-11-22 05:00:00  1056.2083 -0.2  0.7  23.9  34.6
# 1994-11-22 06:00:00  1056.2500 -0.1  2.0  23.9  34.6
# 1994-11-22 07:00:00  1056.2917  0.0  3.1  23.9  34.6
# 1994-11-22 08:00:00  1056.3333 -0.1  2.7  23.9  34.6

# %%
import matplotlib.pyplot as plt
from utilities import tukey53H


u_idx = tukey53H(df['u'], k=1.5)
v_idx = tukey53H(df['v'], k=1.5)

kw = dict(marker='o', linestyle='none', color='crimson', alpha=0.3)
fig_kw = dict(figsize=(7, 5.5), nrows=2, sharey=True, sharex=True)

fig, (ax0, ax1) = plt.subplots(**fig_kw)

df['u'].plot(ax=ax0)
df['u'][u_idx].plot(ax=ax0, **kw)

df['v'].plot(ax=ax1)
df['v'][v_idx].plot(ax=ax1, **kw)

_ = ax0.set_ylim(-55, 55)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-b3a9e649d095> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 from utilities import tukey53H
#       3
#       4
#       5 u_idx = tukey53H(df['u'], k=1.5)
#
# /home/filipe/.virtualenvs/blog/lib/python2.7/site-packages/utilities/__init__.py in <module>()
#      10
#      11 # External (legacy code).
# ---> 12 from tardis import *
#      13
#      14 __version__ = '0.3.0'
#
# /home/filipe/.virtualenvs/blog/lib/python2.7/site-packages/tardis/__init__.py in <module>()
#       2
#       3
# ----> 4 from .tardis import *
#       5
#       6 __version__ = '0.2.0'
#
# /home/filipe/.virtualenvs/blog/lib/python2.7/site-packages/tardis/tardis.py in <module>()
#       9 from pysgrid.custom_exceptions import SGridNonCompliantError
#      10
# ---> 11 from .slices import find_bbox
#      12 from .utils import wrap_lon180, is_model
#      13
#
# /home/filipe/.virtualenvs/blog/lib/python2.7/site-packages/tardis/slices.py in <module>()
#       5 import iris
#       6
# ----> 7 from .coords import x_coord, y_coord, z_coord, t_coord
#       8
#       9 iris.FUTURE.netcdf_promote = True
#
# ImportError: No module named coords

# %%
import numpy as np
from pandas import rolling_median

def is_spike(series, window_size=3, threshold=3, scale=False):
    medians = rolling_median(series, window=window_size, center=True)
    medians = medians.fillna(method='bfill').fillna(method='ffill')
    difference = np.abs(series - medians)
    if scale:
        return difference > (threshold*difference.std())
    return difference > threshold

# %%
from pandas import Series, date_range

series = [33.43, 33.45, 34.45, 90.0, 35.67, 34.9, 43.5, 34.6, 33.7]
series = Series(series, index=date_range('1980-01-19', periods=len(series)))

is_spike(series, window_size=3, threshold=3, scale=True)

# %%
u_idx = is_spike(df['u'].copy(), threshold=3)
v_idx = is_spike(df['v'].copy(), threshold=3)

# %%
fig, (ax0, ax1) = plt.subplots(**fig_kw)

df['u'].plot(ax=ax0)
df['u'][u_idx].plot(ax=ax0, **kw)

df['v'].plot(ax=ax1)
df['v'][v_idx].plot(ax=ax1, **kw)

_ = ax0.set_ylim(-55, 55)

# %%
HTML(html)

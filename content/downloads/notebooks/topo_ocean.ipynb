# %%
from IPython.core.display import HTML

with open('creative_commons.html', 'r') as f:
    html = f.read()
    
with open('./styles/custom.css', 'r') as f:
    styles = f.read()
    
HTML(styles)
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
# /*        margin-left:16% !important;
#         margin-right:auto;*/
#         margin-left:auto;
#         margin-right:16% !important;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h2 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 135%;
#         font-size: 120%;
#         width:600px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
# /*    .prompt{
#         display: None;
#     }*/
# ...

# %% [markdown]
# <!-- PELICAN_BEGIN_SUMMARY -->
# Nice colormap with brewer2mpl.
# <!-- PELICAN_END_SUMMARY -->

# %% [markdown]
# I already used the [brewer2mpl](https://github.com/jiffyclub/brewer2mpl) module in previous posts.  So this post is to draw attention to this interesting module that can easily access and the [Colorbrewer2.0](http://colorbrewer2.org/) website and convert colormaps directly to matplotlib.

# %% [markdown]
# As let's start importing by `cartopy`, `iris`, `pyplot`, and `numpy`.

# %%
import numpy as np
import matplotlib.pyplot as plt

import iris
import iris.plot as iplt
import cartopy.crs as ccrs
import iris.quickplot as qplt

from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

# %% [markdown]
# We will plot a topography map using the [etopo1](http://www.ngdc.noaa.gov/mgg/global/) dataset at a NOAA opendap server.  With `iris` we can slice the data before downloading the data.  Finally we will "print" our cube to check the metadata.

# %%
url = 'http://www.ngdc.noaa.gov/thredds/dodsC/relief/ETOPO1/thredds/ETOPO1_Bed_g_gmt4.nc'
constraint = iris.Constraint(coord_values={'latitude':lambda cell: -25 <= cell <= -22,
                                           'longitude': lambda cell: -46 <= cell <= -42})
bathy = iris.load_cube(url, constraint)
print(bathy)
# Out:
# z / (unknown)                       (latitude: 180; longitude: 241)
#      Dimension coordinates:
#           latitude                           x               -
#           longitude                          -               x
#      Attributes:
#           Conventions: COARDS/CF-1.0
#           GMT_version: 4.4.0
#           actual_range: [-10898.   8271.]
#           node_offset: 0
#           title: ETOPO1_Bed_g_gmt4.grd

# %% [markdown]
# Now we will use `brewer2mpl` to create two color pallets, one with **Greens** for land and another with **Blues** for the ocean.  We reverse the ocean pallet because we want the darker blue at deeper depths.  In addintion, we will cap the first two "greens" to get a darker shade if green at the highest heights.  Finally, we concatenate both colors and convert them to matplotlib values.

# %%
from brewer2mpl import brewer2mpl

land = brewer2mpl.get_map('Greens', 'sequential', 9)
ocean = brewer2mpl.get_map('Blues', 'sequential', 7, reverse=True)

colors = np.array(ocean.mpl_colors + land.mpl_colors[2:])

levels = [-4000, -2500, -1000, -700, -400, -145, -10, 0, 10, 145, 400, 800, 1200, 1600]

# %%
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(projection=ccrs.PlateCarree()))
qplt.contourf(bathy, levels, colors=colors, extend='both')
ax.coastlines('10m', color='k')
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1.5, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_right = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
iplt.citation('Inspired by\nhttp://nbviewer.ipython.org/5254237')

# %% [markdown]
# Much easier (and more readable) then the old [MatlabTM way](http://guillaumemaze.googlecode.com/svn/trunk/matlab/codes/colors/newclim.m) which in turn still needs to get an overlay of the subplots making the code look even work!

# %% [markdown]
# Check this post at [*nbviewer*.](http://nbviewer.ipython.org/urls/raw.github.com/ocefpaf/python4oceanographers/master/content/downloads/notebooks/topo_ocean.ipynb)

# %%
HTML(html)
# Out:
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/3.0/deed.en_US"><img alt="Creative Commons License"
# style="border-width:0" src="http://i.creativecommons.org/l/by-nc-sa/3.0/88x31.png" /></a><br />
# <span xmlns:dct="http://purl.org/dc/terms/" href="http://purl.org/dc/dcmitype/Dataset" property="dct:title" rel="dct:type">
# "python4oceanographers"</span> by <a xmlns:cc="http://creativecommons.org/ns#" href="http://ocefpaf.github.io/"
# property="cc:attributionName" rel="cc:attributionURL">Filipe Fernandes</a> is licensed under a <a rel="license"
# href="http://creativecommons.org/licenses/by-nc-sa/3.0/deed.en_US">
# Creative Commons Attribution-NonCommercial-ShareAlike 3.0 Unported License</a>.<br />
# Based on a work at <a xmlns:dct="http://purl.org/dc/terms/" href="http://ocefpaf.github.io/"
# rel="dct:source">http://ocefpaf.github.io/</a>.

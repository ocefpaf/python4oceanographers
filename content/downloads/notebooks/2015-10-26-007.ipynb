# %%
name = "2015-10-26-007"

title = "NLTK, maps, and 007"

# %%
# %matplotlib inline

import os
import seaborn
from datetime import datetime
from IPython.core.display import HTML

with open('creative_commons.txt', 'r') as f:
    html = f.read()


hour = datetime.utcnow().strftime('%H:%M')
comments="true"


date = '-'.join(name.split('-')[:3])
slug = '-'.join(name.split('-')[3:])

metadata = dict(title=title,
                date=date,
                hour=hour,
                comments=comments,
                slug=slug,
                name=name)

markdown = """Title: {title}
date:  {date} {hour}
comments: {comments}
slug: {slug}

{{% notebook {name}.ipynb cells[2:] %}}
""".format(**metadata)

content = os.path.abspath(os.path.join(os.getcwd(),
                                       os.pardir,
                                       os.pardir, 
                                       '{}.md'.format(name)))
with open('{}'.format(content), 'w') as f:
    f.writelines(markdown)
    
with open('./styles/custom.css', 'r') as f:
    styles = f.read()


html = """
<small>
<p> This post was written as an IPython notebook.  It is available for
<a href="http://ocefpaf.github.com/python4oceanographers/downloads/
notebooks/%s.ipynb">download</a> or as a static
<a href="http://nbviewer.ipython.org/url/ocefpaf.github.com/
python4oceanographers/downloads/notebooks/%s.ipynb">html</a>.</p>
<p></p>
# %s """ % (name, name, html)


HTML(styles)
# Out:
# /home/filipe/.virtualenvs/blog/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
# /*        margin-left:16% !important;
#         margin-right:auto;*/
#         margin-left:auto;
#         margin-right:16% !important;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h2 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 135%;
#         font-size: 120%;
#         width:600px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
# /*    .prompt{
#         display: None;
#     }*/
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %% [markdown]
# The [Natural Language Toolkit (NLTK)](http://www.nltk.org/) is on of those amazing piece of Software that surprises us just by the fact that it works.
# Just Google it and be amazed!
#
# Recently I found the module [geograpy](https://pypi.python.org/pypi/geograpy) which extract geographical information (countries, regions and cities) from texts using NLTK.
#
# So why not make a post with something I always wanted to try (NLTK), with something I like (maps)?  First let's take a look at how `geograpy` works.

# %%
import geograpy

text = "Paris is the city of love!"

places = geograpy.get_place_context(text=text)

places

# %% [markdown]
# Cool!  We get a `PlaceContext` object.  Let's explore this object.

# %%
places.cities
# Out:
# [u'Paris']

# %%
places.countries
# Out:
# [u'France', u'United States', u'Canada']

# %% [markdown]
# Anyone reading the phrase knows I meant the mud tidal flat city of [Lutetia](https://en.wikipedia.org/wiki/Paris#Origins) and not the other two cities named Paris in USA and CA.
# That is a limitation of automated text parsers, it cannot interpret the context like humans do.  Still... That is pretty amazing!
#
# That task gets even more complicated when the city name in British.
# You'll get returns all over the [Empire](https://what-if.xkcd.com/48/)!

# %%
city = "Victoria"
text = "How many countries with a city named {} can you find?".format(city)

places = geograpy.get_place_context(text=text)
countries = places.countries

print('Found {} countries for the city {}:\n{}'.format(len(countries), city, ', '.join(countries)))
# Out:
# Found 12 countries for the city Victoria:
# United States, Canada, Seychelles, United Kingdom, Malta, Romania, Malaysia, Mexico, Chile, Argentina, Trinidad and Tobago, Panama

# %% [markdown]
# OK.  I cheated by choosing Victoria.  Let's try a more British-like name.

# %%
city = "Richmond"
text = "How many countries with a city named {} can you find?".format(city)

places = geograpy.get_place_context(text=text)
countries = places.countries

print('Found {} countries for the city {}:\n{}'.format(len(countries), city, ', '.join(countries)))
# Out:
# Found 4 countries for the city Richmond:
# United Kingdom, United States, Australia, Canada

# %% [markdown]
# I guess that this is enough to make the point that there will be plenty of false positives.
# With that in mind let's try something more challenging.
#
# The new Bond movies is coming up and, as a fan, I am excited to see the it.
# While I wait for the movie let's parse all Ian Fleming's books and find out how many places in the world has 007 used his license to kill.
#
# I will explain the code in the cells below using bad Bond puns.

# %% [markdown]
# ### Chunked, not stirred.

# %%
def utf8toascii(text):
    return text.decode("utf-8").encode("ascii", "ignore")


def read_in_chunks(file_object, chunk_size=2048):
    while True:
        data = file_object.read(chunk_size)
        if not data:
            break
        yield data

# %% [markdown]
# ### I've been expecting you, Mr Loop.

# %%
import os
import cPickle as pickle

if not os.path.exists('./data/books.pickle'):
    import geograpy
    from glob import glob

    books = dict()
    for book in glob('*.txt'):
        countries = []
        with open(book) as f:
            for chunk in read_in_chunks(f):
                try:
                    chunk = utf8toascii(chunk)
                    p = geograpy.get_place_context(text=chunk)
                except UnicodeDecodeError:
                    pass  # End of data.
                countries.extend(p.countries)
        book_name = book.split('.txt')[0]
        books.update({book_name: countries})

    with open('./data/books.pickle', 'wb') as f:
        pickle.dump(books, f)
else:
    with open('./data/books.pickle', 'rb') as f:
        books = pickle.load(f)

# %% [markdown]
# ### So we meet again.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from collections import Counter


dfs = []
for book, countries in books.items():
    book = book.split('-ian_fleming')[0]
    labels, values = zip(*Counter(countries).items())
    dfs.append(pd.DataFrame(np.array(values), index=labels, columns=[book]))

df = pd.concat(dfs, axis=1)

all_books = df.T.sum().sort_index()

# %% [markdown]
# ### World domination. The same old dream.

# %%
if not os.path.exists('./data/positions.pickle'):
    import time
    from geopy import GeoNames
    from geopy.geocoders.base import GeocoderTimedOut

    positions = dict()
    geolocator = GeoNames(username='ocefpaf')
    for country in df.index:
        while True:
            try:
                position = geolocator.geocode(country)
            except:
                time.sleep(5)
                continue
            break
        if position:
            location = [position.latitude, position.longitude]
            positions.update({country: location})
            del position
        else:
            print("Could not get position for {}".format(country))
    with open('./data/positions.pickle', 'wb') as f:
        pickle.dump(positions, f)
else:
    with open('./data/positions.pickle', 'rb') as f:
        positions = pickle.load(f)

# %%
import folium

mapa = folium.Map(tiles="Cartodb dark_matter", location=[0, 0], zoom_start=2)


for country, location in positions.items():
    times = int(all_books[country])
    popup = "{} was mentioned {} times.".format(country, times)
    mapa.simple_marker(location=location, popup=popup,
                       marker_icon="ok",
                       marker_color="orange",
                       clustered_marker=True)
mapa
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#   <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/andrewgiessel/leafletstuff/master/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_1e0f732fbe9344b2adecc1caceb83d7d&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: '(c) <a href=&quot;http://www.openstreetmap.org/copyright&quot;>OpenStreetMap</a> contributors (c) <a href=&quot;http://cartodb.com/attributions&quot;>CartoDB</a>, CartoDB <a href =&quot;http://cartodb.com/attributions&quot;>attributions</a>'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_1e0f732fbe9344b2adecc1caceb83d7d', {
#                                        center:[0, 0],
#                                        zoom: 2,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       /*
#       addition of the image layers
#       */
#
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'orange',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([60.10867,
# 							-113.64258],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;Canada was mentioned 706 times.&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'orange',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([39.75,
# 							59.66667],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;Turkmenistan was mentioned 1 times.&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'orange',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([46.83333,
# 							-56.33333],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;Saint Pierre and Miquelon was mentioned 4 times.&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'orange',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([9.0,
# 							39.5],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;Ethiopia was mentioned 2 times.&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'orange',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([-34.0,
# 							-64.0],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;Argentina was mentioned 66 times.&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'orange',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([8.1,
# 							-1.2],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;Ghana was mentioned 1 times.&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'orange',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([25.0,
# 							45.0],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;Saudi Arabia was mentioned 3 times.&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'orange',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([46.08333,
# 							15.0],
# 							{'icon':marker_8_icon}
# 							);
#       marker_8.bindPopup(&quot;Slovenia was mentioned 2 times.&quot;);
#       marker_8._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_8)
#
#       var marker_9_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'orange',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_9 = L.marker([15.5,
# 							-90.25],
# 							{'icon':marker_9_icon}
# 							);
#       marker_9.bindPopup(&quot;Guatemala was mentioned 3 times.&quot;);
#       marker_9._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_9)
#
#       var marker_10_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor: 'orange',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_10 = L.marker([44.25,
# 							17.83333],
# 							{'icon':marker_10_icon}
# 							);
#       marker_10.bindPopup(&quot;Bosnia and Herzegovina was mentioned 3 times.&quot;);
#       marker_10._popup.options.maxWidth = 300;
#       clusteredmarkers.addLayer(marker_10)
#
#       var marker_11_icon = L.AwesomeMarkers.icon({ icon: 'ok',markerColor:

# %% [markdown]
# I am pretty Uruguay was not mentioned 52 times in Ian Fleming's novels.
# But I 139 mentions of Russia sounds about right ;-)

# %%
HTML(html)
# Out:
# <small>
# <p> This post was written as an IPython notebook.  It is available for
# <a href="http://ocefpaf.github.com/python4oceanographers/downloads/
# notebooks/2015-10-26-007.ipynb">download</a> or as a static
# <a href="http://nbviewer.ipython.org/url/ocefpaf.github.com/
# python4oceanographers/downloads/notebooks/2015-10-26-007.ipynb">html</a>.</p>
# <p></p>
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img
# alt="Creative Commons License" style="border-width:0"
# src="http://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br /><span
# xmlns:dct="http://purl.org/dc/terms/"
# property="dct:title">python4oceanographers</span> by <a
# xmlns:cc="http://creativecommons.org/ns#" href="http://ocefpaf.github.io/"
# property="cc:attributionName" rel="cc:attributionURL">Filipe Fernandes</a> is
# licensed under a <a rel="license"
# href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons
# Attribution-ShareAlike 4.0 International License</a>.<br />Based on a work at <a
# xmlns:dct="http://purl.org/dc/terms/" href="http://ocefpaf.github.io/"
# rel="dct:source">http://ocefpaf.github.io/</a>.
